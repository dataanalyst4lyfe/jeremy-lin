# %% [markdown]
# Game Plan:
#
# - Read in the Blogs & Tags
# - Generate Feature Vectors
#     * Version 1: Naive approach - Use All Words
#     * Version 2: Filter overly common and rare words
#     * Version 3: Only use adjectives & nouns (May need NER)
#     * Version 4: Investigate topic modeling
#     * Version 5: n-grams
# - Apply Machine Learning Algorithm
#     * Naive Bayes
#     * kNN
#     * K-Means
#     ...
# - Evaluate Results
#     * Manual Evaluation
#     * Categorical Evaluation (Maybe use F-Score)

# %% [markdown]
# Read in data

# %%
import os

script_directory = os.getcwd()
relative_file_path = 'data\cleaned up (final).txt'
INPUT_FILE_PATH = os.path.join(script_directory, relative_file_path)

print(script_directory)

input_file = open(INPUT_FILE_PATH, 'r', encoding='utf-8')

all_titles = list()
all_blog_entries = list()
all_tags = list()

while True:
    title_line = input_file.readline().strip()
    blog_line = input_file.readline().strip()
    tag_line = input_file.readline().strip()
    tag_list = tag_line.split(',')

    input_file.readline() # This is just to burn the extra new line
    #print("Title: {}\nBlog: {}\nTags: {}\n".format(title_line, blog_line[:100], tag_line))
    #print(tag_list)

    # We only care about entries that have blog entries
    if tag_line:
        all_titles.append(title_line)
        all_blog_entries.append(blog_line)
        all_tags.append(tag_list)
    else:
        print("End of File")
        print("Title: {}\nBlog: {}\nTags: {}\n".format(title_line, blog_line[:100], tag_line))
        break # EOF

print("Title Entries: {}".format(len(all_titles)))
print("Blog Entries:  {}".format(len(all_blog_entries)))
print("Tag Entries:   {}".format(len(all_tags)))
# Out:
# D:\Jupyter Projects
# End of File
# Title:
# Blog:
# Tags:
#
# Title Entries: 970
# Blog Entries:  970
# Tag Entries:   970

# %% [markdown]
# Convert to Feature Vectors

# %%
# Experimentation, just trying to unsupervised cluster them

# Code is based off of https://stackoverflow.com/questions/10526579/use-scikit-learn-to-classify-into-multiple-categories

from sklearn.feature_extraction.text import CountVectorizer
count_vector = CountVectorizer()
training_counts = count_vector.fit_transform(all_blog_entries)

print(training_counts.shape)
print(count_vector.vocabulary_.get(u'the'))

# Normalize the vector counts by diving by document length (TF - Term Frequency)
from sklearn.feature_extraction.text import TfidfTransformer
tf_transformer = TfidfTransformer(use_idf=False).fit(training_counts)
training_tf = tf_transformer.transform(training_counts)
print(training_tf.shape)



# Training a Classifier
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import LinearSVC
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.preprocessing import MultiLabelBinarizer

X_train = np.array(all_blog_entries)
y_train = all_tags

#print(y_train)

#return

# Convert Training Array to Binary Array
mlb = MultiLabelBinarizer()
y_train_binary_array = mlb.fit_transform(y_train)

# print(y_train_binary_array)

#X_test = np.array([all_blog_entries[0], all_blog_entries[1]])
X_test = np.array(all_blog_entries[100:125])   
target_names = list(mlb.classes_)

#print(X_test)
#print(target_names)
#print(len(target_names))
#print("\n\n\n\n\n")

classifier = Pipeline([ \
    ('vectorizer', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', OneVsRestClassifier(LinearSVC()))])
classifier.fit(X_train, y_train_binary_array)
predicted = classifier.predict(X_test)
predicted_as_string = mlb.inverse_transform(predicted)

print("\n")

#for item, labels in zip(X_test, predicted_as_string):
#    print('%s => %s' % (item[100:], ', '.join(target_names[x] for x in labels)))

for item, labels in zip(X_test, predicted_as_string):
    print("\n{} => \n\t{}".format(item[:100], labels))
# Out:
# (970, 27747)
# 24328
# (970, 27747)
#
#
#
# yes weve finally done it liferays community wiki has been migrated from mediawiki to liferays own wi =>
# 	('migration', 'wiki')
#
# the much awaited liferay 51 bits are now available for download one of the features that i worked on =>
# 	('glassfish v3', 'osgi')
#
# recently openportal portlet container was fully integrated in liferay portal the openportal portlet  =>
# 	('jsr 286', 'jsr-286', 'portlet container', 'portlet v2.0', 'portlets')
#
# opensso is an open source project for single sign on from sun microsystems this document describes h =>
# 	('liferay  opensso  glassfish',)
#
# brian just wrote a great blog about the meetup and i couldnt resist adding my usual philosophical sh =>
# 	('collaboration', 'liferay', 'meetup', 'social')
#
# weve made some enhancements to the search infrastructure of the portal recently we abstracted out lu =>
# 	('5.1.1', 'search engine', 'solr')
#
# the opensource software movement also known as the free software movement received a boost wednesday =>
# 	('open source',)
#
# if you want to share data between portlets a common way to do that is by storing data in the users s =>
# 	('inter portlet communication', 'ipc', 'session', 'sessions', 'shared data')
#
# perhaps im dating myself but when i entered college in 1988 the computer science department required =>
# 	('mac', 'mac os x')
#
# update here is a video+transcript of the presentation given at the jsfone conference and here is a s =>
# 	('ajax', 'ajax push', 'comet', 'icefaces', 'inter portlet communication', 'ipc', 'jsf', 'portlet')
#
# some people might be wondering why ive been so scarce around here the reason for this is that i and  =>
# 	('courses', 'liferay development', 'portal administration', 'system administration', 'training')
#
# in liferay we have this cool new feature to run portlets as embedded widgets from any webpage anywhe =>
# 	('desktop', 'portlets')
#
# there has been few queries in the liferay forums wrt to support for wsrp webservices for remote port =>
# 	('wsrp openportal version2.0 v2 wsrp2 liferay',)
#
# i just finished a new feature for the message boards portlet the new feature consist of a mechanism  =>
# 	('mailing list', 'message boards')
#
# recently a coleague asked if it was possible to call java from xsl it is possible and here is the ex =>
# 	('cms', 'journal', 'template', 'xsl')
#
# i am pleased to announce the availability of the liferay administrators guide second edition the gui =>
# 	('administration', 'documentation', 'portal administration')
#
# recently my friend journal vm template was feeling a little down in the dumps because of his lack of =>
# 	('cms journal', 'journal', 'template', 'velocity')
#
# liferay is shining in building dynamic contentrich and adserving web sites sesame street and sesame  =>
# 	('alfresco', 'liferay', 'openx')
#
# late last year we started the process of upgrading our performance testing environments our previous =>
# 	('benchmarking', 'performance')
#
# recently i was again asked how to call a more complex liferay service using xsl here is an example o =>
# 	('cms', 'journal', 'services', 'template', 'xsl')
#
# update feb 1 2011 the default permission algorithm from version 60+ is now 6 it uses a fast bitmask  =>
# 	('algorithm 5', 'algorithm 6', 'permissions', 'permissions.user.check.algorithm', 'rbac')
#
# update march 17 2011 this blog post refers to an old version of icefaces 18 i would encourage you to =>
# 	('ajax', 'ajax push', 'icefaces', 'icefaces jsf portlet', 'inter portlet communication', 'ipc', 'liferay developing deploying portlets', 'portlets', 'webinar')
#
# youve been heard out of box siteminder integration is here computer associates ca siteminder is a ce =>
# 	('integration', 'siteminder', 'sso')
#
# a number of important issues have been addressed 512 is a highly recommended upgrade highlights incl =>
# 	('release',)
#
# lately liferay has been following a trend toward externalizing extensibility features as much as pos =>
# 	('configuration', 'plugins', 'portal.properties')

# %% [markdown]
# Now to split test & training data

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn import svm

X_train, X_test, y_train, y_test = train_test_split(all_blog_entries, all_tags, test_size=0.2, random_state=0)

X_train = np.array(X_train)
X_test = np.array(X_test)

# Note to self:
# X_train => y_train
# X_test => y_test

print("X_train: {}".format(X_train.shape))
print("y_train: {}".format(len(y_train)))
print("X_test:  {}".format(X_test.shape))
print("y_test:  {}".format(len(y_test)))

# Convert Training Array to Binary Array
mlb = MultiLabelBinarizer()
y_train_binary_array = mlb.fit_transform(y_train)

classifier = Pipeline([ \
    ('vectorizer', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', OneVsRestClassifier(LinearSVC()))])
classifier.fit(X_train, y_train_binary_array)
predicted = classifier.predict(X_test)
predicted_as_string = mlb.inverse_transform(predicted)

print("\n")

for item, labels in zip(X_test, predicted_as_string):
    print("\n{} => \n\t{}".format(item[:100], labels))
# Out:
# X_train: (776,)
# y_train: 776
# X_test:  (194,)
# y_test:  194
#
#
#
# software should be modular it has been a core thought of developers and architects for quite a long  =>
# 	()
#
# starting to recover from jetlag after a two week trip los angeles and liferay retreat one of the thi =>
# 	('maven',)
#
# i took a look at jboss portal and concluded that nothing is wrong with liferay haha buismart guy hah =>
# 	()
#
# objective implement many to many relation in liferay development using service builder tool liferay  =>
# 	()
#
# ive learned a lot while writing liferay in action im going through my final edits now before the boo =>
# 	()
#
# you probably know the basic installation instructions for liferay bundles unzip and run startupsh wi =>
# 	()
#
# publish version hook plugin this article is described about the custom publish version hook which is =>
# 	()
#
# my very first blog post to be honest ive said for months that i was going to start doing this but th =>
# 	()
#
# last friday i had the pleasure of attending our very first roadshow which was hosted together with o =>
# 	()
#
# the latest release of liferay ide version 160 has been made available today head over to the downloa =>
# 	('development', 'eclipse', 'ide')
#
# one of the topics ive seen over and over on the forums is confusion over the configuration of hot de =>
# 	()
#
# content friendly url this is one of those tidbits you get served on a platter if youre lucky enough  =>
# 	()
#
# the portal provides remote staging and publishing capability through which the users can select subs =>
# 	()
#
# the more refined staging along with liferay portal 62 has been out for a while and you might have re =>
# 	()
#
# did you like what you saw in previous milestones you didnt feel there was enough meat to be worth yo =>
# 	()
#
# in this document basically we will understand about roles and permissions backend process and its ta =>
# 	()
#
# ever wanted to explicitly define what page to display on the current pagination content from a url p =>
# 	()
#
# in summary the portal 60 or above supports six different types of plugins outofthebox they are portl =>
# 	()
#
# weve finally released both ce and ee versions of liferay 61 ga3 and along with those releases weve a =>
# 	()
#
# libraries or jarfiles if you will exist in many different locations in your liferay installation som =>
# 	()
#
# a few weeks ago i blogged about tomcats jni native library recently i have been at a client site try =>
# 	()
#
# yes i know i didnt keep my previous promise to quickly follow up with the next episode thus im not p =>
# 	('radio liferay',)
#
# last week we had a casual game night to relieve some stress and to become more familiar with the new =>
# 	()
#
# hi guysone of the many great improvements of liferay 6 is the workflow system as many of you already =>
# 	()
#
# introduction to liferay portal liferay is portlet technology which follows the jsr 168 and jsr 286 c =>
# 	('portlet',)
#
# hi there as you may have already seen the userorganization administration in liferay 52 has been com =>
# 	()
#
# since we havent been announcing it much youre probably unaware that weve recently started making wee =>
# 	()
#
# hey friends do you know the use of beanshell script which is coming up with liferay control panel i  =>
# 	()
#
# this is not really a technical post in what follows i share two little tips for liferay 62 users thi =>
# 	()
#
# just few words to explain how to customize the behaviour when the liferay session expires no hook th =>
# 	()
#
# introduction liferay have very good content management system we can design and publish content in t =>
# 	()
#
# as as followup to the helios compatible release of liferay ide v101 i wanted to let everyone know th =>
# 	('development', 'eclipse', 'ide')
#
# i have the privilege of speaking about social networking portlets with icefaces ajax push at the fol =>
# 	('icefaces',)
#
# nimen hao hi yall we just released version 15 of liferay ide eclipse plugins from your eclipse insta =>
# 	('development', 'eclipse', 'ide')
#
# corporate portals open source the alternative jorge ferrer director general of spain 24022010 95404  =>
# 	()
#
# taking a short break from the vuejs portlet because i had to implement a repository proxy since i wa =>
# 	()
#
# liferay for your ears i had the opportunity to record a session with 34 of the founders namely all t =>
# 	('radio liferay',)
#
# liferays objects are being encapsulated into assets documents web contents blog entries are being en =>
# 	()
#
# radio liferay is back with a repeat guest james falkner liferays community manager like last year sy =>
# 	('radio liferay',)
#
# the past couple of years ive seen many examples of using liferays builtin json services in various w =>
# 	()
#
# i know that some people are suggesting using the setenvsh script to control jvm settings for tomcatn =>
# 	()
#
# suppose that you a portlet developer need to develop a faq portlet that displays questions and answe =>
# 	()
#
# liferay welcomes new chief marketing officer independent open source leader liferay accelerates targ =>
# 	()
#
# some of you who may have been to this years north american symposium you may have heard bryan cheung =>
# 	()
#
# if you are a netbeans user and always wanted to try portal pack with latest netbeans 69 and liferay  =>
# 	('netbeans', 'portal pack', 'portalpack')
#
# as part of my work on jsr 314 jsf 20 ive been reviewing the specification javadocs and tag library d =>
# 	()
#
# this is an adaptation of a blog i wrote for wolters kluwer march 2011 everyone knows that data and i =>
# 	()
#
# in my previous blog i wrote about gadgetwidget and how we can use it in liferay liferay provide grea =>
# 	('gadget', 'opensocial')
#
# lets have another community meeting this time ill be able to speak the local language 5 september 19 =>
# 	()
#
# weve been working in the last few days with our partner vass defining the best design for a very lar =>
# 	()
#
# perhaps im dating myself but when i entered college in 1988 the computer science department required =>
# 	()
#
# liferay and pentaho announce technology partnership orlando fl oct 23 2007 liferay provider of the w =>
# 	('press release',)
#
# my apologies for the long break in publishing the episodes i got distracted with a lot of work and o =>
# 	('radio liferay',)
#
# you may have seen a previous mention of the community bugsquad program in my last community roundup  =>
# 	()
#
# the liferay core engineering team and the sun engineering team are collaborating to implement the us =>
# 	()
#
# federated search is the simultaneous search of multiple online databases or web resources and it is  =>
# 	()
#
# fckeditor 265 or ckeditor 3x is the only editor to bring you a zero installation spell check as you  =>
# 	()
#
# most of the client and potential client locations ive visited in china have been in big crowded metr =>
# 	()
#
# digital transformation of learning is changing the way we learn and develop today technology enables =>
# 	('tin can api', 'valamis', 'xapi')
#
# several months ago i read an article talking about a new concept for me the hacker in residence sinc =>
# 	()
#
# liferay for your ears this time i sat together with alexander chow and sergio gonzález both are life =>
# 	()
#
# introduction wow been staying up late cranking out some vaadin blogs its starting to catch up with m =>
# 	('vaadin 7', 'vaadin control panel')
#
# well im back in our offices in asia to help our sales folks and to sign some partnerships with local =>
# 	()
#
# tomorrow thursday march 18th ill be visiting barcelona to participate in the event la web inteligent =>
# 	()
#
# 2010s benchmark and optimization is reaching the end it is time to write something about what we did =>
# 	()
#
# liferay 6 ee is almost done its great and were having a party over the last year and a half most of  =>
# 	()
#
# portal pack makes life easier yet again this time with the netbeans hook plugin for liferayavailable =>
# 	()
#
# liferay 52 ee and 6 improved the capabilities of ldap integration in many areas refer to blogs posts =>
# 	()
#
# introduction liferay have in built support for rest api so we can create rest web services for plugi =>
# 	()
#
# wow its been a while since i last posted liferay 61 ee has just been released and its changed so muc =>
# 	()
#
# i read an interesting article today you should probably read it first to understand my thoughts but  =>
# 	()
#
# any application dealing with currency should really use the java class bigdecimal bigdecimal javamat =>
# 	()
#
# ok so in the last post i talked about jsp include buffer that post talked about how youd override js =>
# 	('theme',)
#
# im not sure if everyone out there surfing the interwebs has noticed but weve been quietly releasing  =>
# 	()
#
# you probably know the basic installation instructions for liferay bundles unzip and run startupsh wi =>
# 	()
#
# liferay is in the initial phase of semantically versioning all its java source code yay what if you  =>
# 	('build system', 'semantic versioning')
#
# its my return guest show time heres another one however youve unfortunately never heard my first rec =>
# 	('radio liferay',)
#
# twentytwelve was the year i ran like forrest gump in april i began my quest by training for a 10k tw =>
# 	()
#
# the previous versions of liferay portal already supported rtl righttoleft text in limited way but si =>
# 	()
#
# introduction so vaadin provides a core set of widgets standard widgets that youd find in any web fra =>
# 	('vaadin 7', 'vaadin control panel')
#
# liferay and icefaces announce ajax portal technology partnershipproduct integration provides rich us =>
# 	('icefaces',)
#
# ive seen a tone of requests lately for how to add expando tables and columns programatically during  =>
# 	()
#
# in liferay 6x scheduled tasks were kind of easy to implement i mean youd implement a class that impl =>
# 	()
#
# youve been heard out of box siteminder integration is here computer associates ca siteminder is a ce =>
# 	()
#
# in a recent blog ross dawson ceo of advanced human technologies notes liferay is identified by gartn =>
# 	()
#
# freemarker has some nice native support for working with json and with the help of a few liferay uti =>
# 	()
#
# first of all a belated happy new year this is my first blog post in the new year and in the new them =>
# 	()
#
# step 1 liferay migration to 606 1 create 523 db dump dbsql 2 create database for lr 606 db606 3 load =>
# 	()
#
# so my last blog post involved a classloader trick for velocity but it also involved a problem of dyn =>
# 	()
#
# after the first release version 10 with the focus on stability and the most fundamental features we  =>
# 	()
#
# hi everyonejust wanted to let you all know about tweetray tweetray is a way for multiple people to p =>
# 	()
#
# recently i came across a forum post asking about deploying liferay on amazons elastic beanstalk elas =>
# 	()
#
# when working with liferay sometimes you might encounter classpath issues during ant builds i have a  =>
# 	()
#
# doxygen output for liferay 7 ce ga1 visualize liferay classes methods with the help of uml inheritan =>
# 	()
#
# there might be cases when you want to write your own cas custom authentication service for authentic =>
# 	()
#
# this blog is part of a series of entries on mobile first with liferay screens part 1 part 2 part 3 m =>
# 	('liferay screens', 'mobile', 'mobile first with liferay screens')
#
# a new functionallity in liferay 6 are the so called sanitizers what are sanitizers sanitizers are a  =>
# 	()
#
# recently i did a liferay live presentation on driving community participation with liferay ill post  =>
# 	()
#
# we continue our path towards releasing liferay 7 with a new alpha release that focuses on fixing bug =>
# 	('liferay 7',)
#
# just a quick note vaadin 750 was released at the end of june 2015 ive completed an initial round of  =>
# 	()
#
# while at oscon last month i couldnt help but notice a lot of chatter between the booths about mobile =>
# 	()
#
# jrebel has changed the way developers code in java never again will you need to redeploy your applic =>
# 	()
#
# here i am again for a second entry on the series of liferay architecture this time im going to talk  =>
# 	()
#
# update the expandomongodbhook plugin is now committed to svn and available from trunk over the past  =>
# 	()
#
# traveling a lot lately ive had to take some measures to get some american tv so i set up a slingbox  =>
# 	()
#
# its hard enough to get certain developer types to mingle for even a little while without constantly  =>
# 	()
#
# the much awaited liferay 51 bits are now available for download one of the features that i worked on =>
# 	()
#
# one of the current frontend trends is seems to be angularjs last week we had helsinkijs meetup and a =>
# 	()
#
# several months ago i had asked stephanie may if there were any volunteer opportunities with world im =>
# 	()
#
# this weeks guest is neil griffin liferays resident jsf wizard lead engineer for liferay faces and re =>
# 	('jsf',)
#
# wouldnt it be nice to take pictures with my mobile phone and let liferay categorize organise these p =>
# 	()
#
# some weeks ago we announced the preview release of alloyui 20 one of the cool things about it is tha =>
# 	()
#
# our friends at sesame street continue to raise the bar when it comes to being culturally relevant fo =>
# 	()
#
# note the following blog post is about vaadin 6 and liferay ill be doing future posts on vaadin 7 but =>
# 	('vaadin 7', 'vaadin control panel')
#
# join us for 2 days of collaboration training and networkingthe liferay west coast symposium is here  =>
# 	()
#
# during a recent class i taught on icefaces one of my students asked me why the calendar was often on =>
# 	()
#
# as we all know liferay 7 dxp come with new featuresimprovements including functionalarchitectural on =>
# 	()
#
# so weve been operational for a little over two months now and this is how we do it over here at the  =>
# 	()
#
# liferay 52 ee and 6 improved the capabilities of ldap integration in many areas refer to blogs post  =>
# 	()
#
# one of the things i was looking forward to when starting with liferay was the opportunity to work at =>
# 	()
#
# opensso is an open source project for single sign on from sun microsystems this document describes h =>
# 	()
#
# the word is out in twitter we have released the first development milestone release of liferay 7 thi =>
# 	()
#
# mark benioff the ceo of salesforcecom wrote a guest post for techcrunch entitled the facebook impera =>
# 	()
#
# are you new to liferay found liferay and want to know what it can do for you or are you with liferay =>
# 	()
#
# are you new to liferay found liferay and want to know what it can do for you or are you with liferay =>
# 	()
#
# if you are new using liferay and you want to develop your first project please check all your resour =>
# 	()
#
# in ten steps you could be able to set alfresco 31 or above web client as a set of portlets in lifera =>
# 	()
#
# while its nice to blog about some of the tools i use see the below posts on virtualbox and the lombo =>
# 	()
#
# there have been some pretty interesting and important changes regarding social equity for liferay 61 =>
# 	()
#
# as you probably know in liferay we are working on a new and exiting project called liferay screens i =>
# 	()
#
# have you ever faced github pull request bug which manifests in a way that list of peopole you want t =>
# 	()
#
# as you have been noticed the version 61 adds a lot of cms document library features the following is =>
# 	()
#
# part 1 setting up solr with tomcat step 1 download solr its just a zip file step 2 copy from your so =>
# 	()
#
# another devcon private session i missed his presentations but got the summary right when he was done =>
# 	('radio liferay',)
#
# valamis 24 enterprise edition release new features summary valamis 24 enterprise edition has been re =>
# 	('experience api', 'learning management system', 'learning record store', 'valamis')
#
# liferay expands to chinacompany opens dalian officein response to rapid growthdalian china october 9 =>
# 	()
#
# a continuation of last weeks episode milen dyankov stepped in as a cohost and helped me ask the righ =>
# 	('radio liferay',)
#
# i was learning on how to implement the export and import functionality on liferay initially i though =>
# 	()
#
# introduction so i wanted to provide an example vaadin portlet built using the vaadin 7 shared enviro =>
# 	('vaadin 7',)
#
# liferay portal provides a lot of cool features for example organization hierarchy virtual host and s =>
# 	()
#
# liferay 62 has no longer supports the auidialog auiio etcbut all of them deprecated in 62 we need to =>
# 	()
#
# to continue a recent string of theme related posts im going to add another on the recently added fea =>
# 	()
#
# today im welcoming a repeat guest jorge ferrer liferays vp of engineering ive had the great opportun =>
# 	('radio liferay',)
#
# update 1030 congratulations to the london java community and to cloudbees and thanks to everyone who =>
# 	()
#
# the portal pack 30 is now available for download with lots of new features and bug fixes the portal  =>
# 	('portal pack', 'portalpack')
#
# we can integrate alfresco repository with liferay documents and media portlet by using cmis feature  =>
# 	()
#
# hello everyone not bad for a first post wsrp a rough one as someone told me recently but guess what  =>
# 	()
#
# liferay announces partnership with triton serviceslos angeles ca liferay provider of the worlds lead =>
# 	('press release',)
#
# one of the most important features of the new calendar portlet is the ability of consistently showin =>
# 	()
#
# ever wanted to use a rich text editor rte such as the ck editor in your custom portlet implementing  =>
# 	()
#
# liferay announces availability of liferay social office ee reston va business wire liferay inc annou =>
# 	()
#
# its been a long time and finally radio liferay is back with several episodes in the queue today tomá =>
# 	('radio liferay',)
#
# liferay symposiums bring open source and business communities to life new events bring growing inter =>
# 	('conference', 'europe', 'event')
#
# introduction liferay have every good feature that is custom fields from this we can create additiona =>
# 	()
#
# hi everyone having worked with liferay you are probably well aware of the useful themedisplay the th =>
# 	()
#
# liferays architecture is pretty lean but there are lots of things to learn about it what would you b =>
# 	()
#
# how much do you know about the people who are visiting your website the more you know the greater ch =>
# 	()
#
# as you know liferay 6 integrates workflow system like jbpm or kaleo on any assets finally by this fe =>
# 	('jbpm', 'kaleo', 'workflow')
#
# componence becomes new liferay gold partner for the netherlands dutch portal social media specialist =>
# 	()
#
# im listening to and watching a lot of podcasts lately heres whats on my ipodyeah yeah i still listen =>
# 	()
#
# whats knowledge base or knowledge management km the portlet knowledge base allows authoring articles =>
# 	('5.2', '6.0', 'knowledge base')
#
# in my last blog entry i explained the thought process we followed to improve the dockbar what some o =>
# 	()
#
# i had this plugin for liferay 62 that quite limited in terms of complexity a perfect candidate to tr =>
# 	()
#
# its been awhile since i last posted a blog its not like i had a bunch of avid readers in fact i woul =>
# 	()
#
# this is a new cool feature i worked on with brian and its coming on 61 as well as 60 ee sp2 and 52 e =>
# 	()
#
# liferaycignex form open source services partnership leading open source consulting firm offers integ =>
# 	('cignex',)
#
# importing in eclipse all java classes from osgi modules up to liferay 62 when you opened liferay pro =>
# 	()
#
# last year there was a huge buzz about this new protocol call cmis that just was released at 10 much  =>
# 	()
#
# end of version announcement for liferay portal 51 enterprise edition eeliferay announces end of vers =>
# 	()
#
# alloyui is the engine which drives the ui of all liferay products since it was created in 2009 it ha =>
# 	()
#
# we have been working for a while in the task of integrating liferay translations and pootle the over =>
# 	()
#
# long time no posti do a lot of our customer performance tuning jobs and there are some guiding princ =>
# 	()
#
# an overview of liferay portal 6 enterprise intranetsinstall set up and build a corporate intranet wi =>
# 	()
#
# this weeks guest is jack rider from the mediterrean shore in benidorm he is a real liferay veteran h =>
# 	('radio liferay',)
#
# if you have a maven repository running under https with a selfsigned certificate then building a mav =>
# 	()
#
# so im here late one night and im wondering why liferay is hosting profile pics i mean in this day an =>
# 	()
#
# i just finished a new feature for the message boards portlet the new feature consist of a mechanism  =>
# 	()
#
# if you have been curious about maven or if you would like to use maven to develop liferay plugins we =>
# 	('maven',)
#
# my next home project will be to set up linux media center edition mce which runs on top of kubuntu a =>
# 	()
#
# by now weve heard of the necessity of creating a good experience for our mobile viewers yet were not =>
# 	()
#
# i would like to start saying that this entry is focused on designers and frontends but i think that  =>
# 	()
#
# new liferay portal 40 extendsgreater control to administrators usersopen source portal development t =>
# 	('press release',)
#
# liferay portal provides open source content management and services to major german insurerliferay s =>
# 	('press release',)
#
# a lot of people i run into at trainings and on consulting gigs ask this question how do i access lif =>
# 	()
#
# new liferay faces release facesrequestcontext update there is now a runnable example of the facesreq =>
# 	('jsf',)
#
# i have just came back from 2009 retreat it was really fun a lot of old faces and new faces a lot of  =>
# 	('performance',)
#
# the dao layer of liferay for services persistence had a core hibernate nonjpa implementation but lat =>
# 	()
#
# liferay named a visionary in gartners magic quadrant independent portal leader enjoys continued mark =>
# 	()
#
# the liferay certification team is very happy to announce the availability of the liferay 62 certifie =>
# 	()
#
# new years resolution publish more podcast episodes lets start happy new year wishing you all the bes =>
# 	('radio liferay',)
#
# episode 1 of liferay radio is out im speaking with james falkner liferays community manager we spoke =>
# 	('radio liferay',)
#
# i wrote a new wiki because i saw some gripes in the forums wikiliferaycomindexphpgettingstartedwithl =>
# 	()
#
# a growing number of websites are adopting oauth to authorize thirdparty applications to interact wit =>
# 	()
#
# over the past several months ive been working on integrating an osgi framework into liferay portal t =>
# 	('osgi',)
